# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel("Superstore_USA.xlsx")

# %%
df.shape
# Out:
# (9426, 24)

# %%
df.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1955
# Low              1910
# Not Specified    1866
# Medium           1838
# Critical         1784
# Critical            1
# Name: count, dtype: int64

# %%
df['Row ID'].value_counts()
# Out:
# Row ID
# 18606    1
# 18700    1
# 21617    1
# 19798    1
# 20159    1
#         ..
# 2374     1
# 6400     1
# 3081     1
# 829      1
# 24492    1
# Name: count, Length: 9354, dtype: int64

# %% [markdown]
#  ## UNIVARIATE ANALYSIS
#  <font face="Times New Roman" size="4" > <em> Univariate Exploratory Analysis Involves Examining and Understanding One Variable at a Time. Instead of Looking at Relationships Between Variables, Univariate Analysis Focuses on Exploring the Characteristics and Patterns of Individual Variables in Isolation. </em></font>

# %%
plt.figure(figsize=(6,6))
sns.countplot(x = 'Customer Segment' ,data = df)
plt.gcf().set_facecolor('#f0f0f0')
plt.show()

# %%
df["Product Category"].value_counts()
# Out:
# Product Category
# Office Supplies    5157
# Technology         2312
# Furniture          1885
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="Product Category", data=df)
plt.gcf().set_facecolor('#f0f0f0')
plt.show()

# %%
x= df['Product Sub-Category'].value_counts().index
y= df['Product Sub-Category'].value_counts().values

# %%
plt.figure(figsize=(50,25))
plt.pie(y, labels=x,startangle=60,autopct='%1.1f%%')
plt.rcParams['font.size'] = 40
plt.title(" Product Sub Category")
plt.legend(x)
plt.legend(fontsize = 20, loc= "lower left")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="Ship Mode", data = df)
plt.gcf().set_facecolor('#f0f0f0')
#plt.rcParams['font.size'] = 15
plt.show()

# %%
#df['Product Container'].value_counts()

# %%
plt.figure(figsize=(25,10))
sns.countplot(x='Product Container',data=df)
plt.rcParams['font.size'] = 15
plt.gcf().set_facecolor('#f0f0f0')
plt.show()

# %%
plt.figure(figsize=(35,40))
top_10_values = df['State or Province'].value_counts().head(10)
x= top_10_values.index
y= top_10_values.values
plt.pie(y, labels=x, startangle=20,autopct='%1.1f%%' )
plt.rcParams['font.size'] = 30
plt.title("Top 10 State Rankings With Respect To Purchasing Power")
plt.legend(x)
plt.legend(fontsize='30', loc='upper left')
plt.show()

# %%
last_10 = df['State or Province'].value_counts().tail(10)
x= last_10.index
y= last_10.values
plt.figure(figsize=(35,40))
plt.pie(y, labels=x,startangle=20,autopct='%1.1f%%' )
plt.rcParams['font.size'] = 30
plt.legend(x)
plt.legend(fontsize=30, loc = 'upper left' )
plt.title("Bottom  10 State Rankings With Respect To Purchasing Power")
plt.show()

# %% [markdown]
# ## BIVARIATE ANALYSIS
# <font face="Times New Roman" size="4"><em>Bivariate Exploratory Analysis  Involves Examining Two Variables Simultaneously to Understand Their Relationship. It Focuses on Uncovering Patterns, Dependencies, and Interactions Between Pairs of Variables Using Statistical Techniques and Visualization Methods Which Can Be Futher Used For Carrying Out Accurate Businees Practise .</em></font>

# %%
plt.figure(figsize=(20,7))
sns.countplot(x= 'Customer Segment' ,data = df, hue=  "Product Category", palette='Set1')
plt.legend(fontsize=10, loc = 'upper right' )
plt.gcf().set_facecolor('#f0f0f0')
plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
plt.figure(figsize=(12,7))
plt.gcf().set_facecolor('#f0f0f0')
#sns.countplot(x='Product Category', data = df, hue = '',palette="Set1")
sns.barplot(x = 'Product Category',y= 'Sales' ,data = df)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Product Category', data=df, hue="Product Sub-Category",palette="Set1")
plt.legend(fontsize=10, loc = 'upper right' )
plt.gcf().set_facecolor('#f0f0f0')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product Category', data=df, hue='Product Container',palette="Set2")
plt.legend(fontsize=10, loc = 'upper right' )
plt.gcf().set_facecolor('#f0f0f0')
plt.show()

# %%
plt.figure(figsize=(17,7))
sns.countplot(x='Customer Segment', data=df, hue='Ship Mode',palette="Set1")
plt.gcf().set_facecolor('#f0f0f0')
plt.legend(fontsize=15, loc = 'upper right' )
plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
plt.figure(figsize=(12,7))
plt.gcf().set_facecolor('#f0f0f0')
sns.barplot(x = 'Product Category',y= 'Profit',data = df,color='lightblue')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.barplot(x = 'Product Category',y= 'Discount',data = df,color='lightblue')
plt.show()

# %%
df['year'] = df["Order Date"].dt.year
plt.figure(figsize=(12,8))
sns.countplot(x='year', data=df)
plt.gcf().set_facecolor('#f0f0f0')
plt.title("Sales Per Year")
plt.show()

# %%
plt.figure(figsize=(12,8))
df['year'] = df["Order Date"].dt.year
ax = sns.countplot(x='year', data=df, hue='Product Category', palette = "Set1")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom',  # Adjust va to 'bottom' for count below bars
                fontsize=12, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.gcf().set_facecolor('#f0f0f0')
plt.legend(fontsize=15, loc = 'upper left' )
plt.title('Count of Orders by Year and Product Category')

plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# <font face="Times New Roman" size="5"><strong> Referring The Above Report We Can Easily Say our Sales Per Year Is Increasing Every Year But in Order To Face The Current Market Scenarios And competitors Foloowing Need To Done, Which can futher Result in More Stronger Hold On The Market And A Increase In The Sales.</strong></font>

# %% [markdown]
# ## Point 1
# <font face="Times New Roman" size="4"><em> When we referred to the data from the columns, customer segment with respect to product category "Office Supplies" resulted in the most preferred buying product in every sector. However, when we compared product category with respect to sales, a completely different aspect came before us. Our product category "Furniture" brought more sales and customers to the company, even though "Office Supplies" being the favorite product in every sector .</em></font>

# %% [markdown]
#  ## Point 2 (WITH RESPECT TO  DISCOUNT AND PROFIT)
# <font face="Times New Roman" size="4"><em>Our Company Has Applied The Same Discount That Is 0.4% On Every Product, But Our Product Category "Technology" Brings The Most Sales. Depending On The Sales and Profit We Can Increase The Discount Slightly  On The Remaining Product Which Might Result In More Sales And Profit For The Organization. </em></font>

# %% [markdown]
# ## Point 3 (SHIPPING MODE)
# <font face="Times New Roman" size="4"><em> Curently Our company Is Providing Delivery Using Three Means Of Transport In Which  Regular Air Is the Most used By Our Customers. In Order To use This And Make It As A  advantage For The company We Can formulate A Meeting With The Respecting Company Proving Us With Air Service And May Try Them To Reduce The Cost For Shipping If They Agree We Have 2 Master Plans which Can Bring More Profit To Our Company
#
# 1) We Get The Shipping  Rates Reduce But We Don't Reduce The Shipping Rates From Our Side This Give A Slightly More Profit.
#
# 2)  We Get The Shipping  Rates Reduce And At Same Time We Reduce The Rates On Our Sides, This Can Result In More Customers
#                              Because Of Faster Deleivery, and Also We Can Close The Express Air Delivery Saving Us More Money Resulting In More Profit.</em></font>
